# %% [markdown]
# # Setup

# %%
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'
import numpy as np
import matplotlib.pyplot as plt
import random
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers, models, optimizers, regularizers, backend as K, Sequential
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Dropout
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
import glob

# %% [markdown]
# ### load data

# %%
# Load array
x_train = np.load('driven_damped_pendulum_data_train.npy')
x_val = np.load('driven_damped_pendulum_data_valid.npy')
x_test = np.load('driven_damped_pendulum_data_test.npy')

kappas_tr, betas_tr, As_tr, omegas_tr = np.loadtxt('driven_damped_pendulum_data_params_train.dat', unpack=True)
kappas_va, betas_va, As_va, omegas_va = np.loadtxt('driven_damped_pendulum_data_params_valid.dat', unpack=True)
kappas_te, betas_te, As_te, omegas_te = np.loadtxt('driven_damped_pendulum_data_params_test.dat', unpack=True)

rtimes_tr = np.load('rtimes_tr_driven.npy')
rtimes_va = np.load('rtimes_va_driven.npy')
rtimes_te = np.load('rtimes_te_driven.npy')

answers_tr = np.load('answers_tr_driven.npy')
answers_va = np.load('answers_va_driven.npy')
answers_te = np.load('answers_te_driven.npy')

# %%
rtimes_tr = rtimes_tr.T
rtimes_va = rtimes_va.T
rtimes_te = rtimes_te.T

answers_tr = answers_tr.T
answers_va = answers_va.T
answers_te = answers_te.T

# %%
class Sampling(layers.Layer):
    """Uses (z_mean, z_log_var) to sample z, the vector encoding a digit."""

    def call(self, inputs):
        z_mean, z_log_var = inputs
        batch = tf.shape(z_mean)[0]
        dim = tf.shape(z_mean)[1]
        epsilon = tf.random.normal(shape=(batch, dim))
        return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %% [markdown]
# # Neural Network

# %%
num_hidden_layers = 2
encoding_dim = 5
input_dim = x_train.shape[1]
hidden_dim = 100
batch_size = 512
epochs = 1000
learning_rate = 0.001
regul=0.00013
regul2=0.00019

factor = 0.25
patience = 50
min_lr = 0.000001
verbose = 1

beta = 1

# %%
reduce_lr = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_total_loss',
                                                 factor=factor,
                                                 patience=patience, 
                                                 min_lr=min_lr, 
                                                 verbose=verbose
                                                )

# %%
early_stopping_callback = EarlyStopping(
    patience=patience,
    monitor='val_total_loss',
    mode='min',
    verbose=verbose
)

# %% [markdown]
# ## Autoencoder

# %%
encoder_input = keras.Input(shape=(input_dim,))
rtimes_input = keras.Input(shape=(1,))

#encoder 
x = layers.Dense(5*hidden_dim, activation='relu', activity_regularizer=regularizers.L1(regul2))(encoder_input)
for i in range(num_hidden_layers):
    x = layers.Dense(hidden_dim, activation='relu', activity_regularizer=regularizers.L1(regul2))(x)
z_mean = layers.Dense(encoding_dim, activity_regularizer=regularizers.L1(regul))(x)
z_log_var = layers.Dense(encoding_dim, activity_regularizer=regularizers.L1(regul))(x)

z = Sampling()([z_mean, z_log_var])

decoder_input = keras.Input(shape=(encoding_dim+1,)) #1 -> question

#decoder
x = layers.Dense(hidden_dim, activation='relu', activity_regularizer=regularizers.L1(regul2))(decoder_input)
for i in range(num_hidden_layers-1):
    x = layers.Dense(hidden_dim, activation='relu', activity_regularizer=regularizers.L1(regul2))(x)
x = layers.Dense(5*hidden_dim, activation='relu', activity_regularizer=regularizers.L1(regul2))(x)
decoded = layers.Dense(1, activation='linear')(x)

encoder = keras.Model(encoder_input, [z_mean, z_log_var, z], name='encoder')
decoder = keras.Model(decoder_input, decoded, name='decoder')

# autoencoder = keras.Model([encoder_input, rtimes_input], decoder(tf.concat(values=[encoder(encoder_input)[2], rtimes_input], axis=1)))

# %%
class VAE(keras.Model):
    def __init__(self, encoder, decoder, **kwargs):
        super().__init__(**kwargs)
        self.encoder = encoder
        self.decoder = decoder
        self.total_loss_tracker = keras.metrics.Mean(name='total_loss')
        self.reconstruction_loss_tracker = keras.metrics.Mean(name='recon_loss')
        self.kl_loss_tracker = keras.metrics.Mean(name='kl_loss')

    @property
    def metrics(self):
        return [self.total_loss_tracker,
                self.reconstruction_loss_tracker,
                self.kl_loss_tracker]

    def train_step(self, data):
        with tf.GradientTape() as tape:
            [x_train, rtimes_tr], answers_tr = data
            z_mean, z_log_var, z = self.encoder(x_train)
            dec_inp = tf.concat(values=[z, rtimes_tr], axis=1)
            reconstruction = self.decoder(dec_inp)
            recon_loss = tf.reduce_mean(
                tf.reduce_sum(
                    keras.losses.mse(answers_tr, reconstruction),
                    axis=(-1))) # , 2
            kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
            kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
            total_loss = recon_loss + (beta * kl_loss)
            grads = tape.gradient(total_loss, self.trainable_weights)
            self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
            self.total_loss_tracker.update_state(total_loss)
            self.reconstruction_loss_tracker.update_state(recon_loss)
            self.kl_loss_tracker.update_state(kl_loss)
            return {
                "total_loss": self.total_loss_tracker.result(),
                "recon_loss": self.reconstruction_loss_tracker.result(),
                "kl_loss": self.kl_loss_tracker.result(),
            }
        
    def test_step(self, data):
        [x_test, rtimes_te], answers_te = data
        z_mean, z_log_var, z = self.encoder(x_test)
        dec_inp = tf.concat(values=[z, rtimes_te], axis=1)
        reconstruction = self.decoder(dec_inp)
        recon_loss = tf.reduce_mean(
            tf.reduce_sum(
                keras.losses.mse(answers_te, reconstruction),
                axis=(-1))) # , 2
        kl_loss = -0.5 * (1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var))
        kl_loss = tf.reduce_mean(tf.reduce_sum(kl_loss, axis=1))
        total_loss = recon_loss + (beta * kl_loss)
        self.total_loss_tracker.update_state(total_loss)
        self.reconstruction_loss_tracker.update_state(recon_loss)
        self.kl_loss_tracker.update_state(kl_loss)
        return {
            "total_loss": self.total_loss_tracker.result(),
            "recon_loss": self.reconstruction_loss_tracker.result(),
            "kl_loss": self.kl_loss_tracker.result(),
        }

# %%
vae = VAE(encoder, decoder)
vae.compile(optimizer=keras.optimizers.Adam(learning_rate=learning_rate), run_eagerly=True)

# %% [markdown]
# ## training the model

# %%
fitting_output = vae.fit([x_train, rtimes_tr], answers_tr,
                          epochs=epochs,
                          batch_size=batch_size,
                          validation_data=([x_val, rtimes_va], answers_va),
                          callbacks=[reduce_lr, early_stopping_callback])
# Out:
# Epoch 1/1000
# 28/28 [==============================] - 2s 73ms/step - total_loss: 300.9197 - recon_loss: 300.6045 - kl_loss: 0.3152 - val_total_loss: 308.1956 - val_recon_loss: 307.7650 - val_kl_loss: 0.4306 - lr: 0.0010
# Epoch 2/1000
# 28/28 [==============================] - 2s 77ms/step - total_loss: 271.6530 - recon_loss: 271.0989 - kl_loss: 0.5541 - val_total_loss: 307.2602 - val_recon_loss: 306.3468 - val_kl_loss: 0.9134 - lr: 0.0010
# Epoch 3/1000
# 28/28 [==============================] - 2s 71ms/step - total_loss: 268.4060 - recon_loss: 267.2349 - kl_loss: 1.1711 - val_total_loss: 303.7703 - val_recon_loss: 302.5421 - val_kl_loss: 1.2282 - lr: 0.0010
# Epoch 4/1000
# 28/28 [==============================] - 2s 76ms/step - total_loss: 264.8610 - recon_loss: 263.4421 - kl_loss: 1.4189 - val_total_loss: 304.7792 - val_recon_loss: 302.8983 - val_kl_loss: 1.8809 - lr: 0.0010
# Epoch 5/1000
# 28/28 [==============================] - 2s 86ms/step - total_loss: 264.5829 - recon_loss: 262.5828 - kl_loss: 2.0001 - val_total_loss: 310.5101 - val_recon_loss: 308.3738 - val_kl_loss: 2.1364 - lr: 0.0010
# Epoch 6/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 267.3298 - recon_loss: 265.3190 - kl_loss: 2.0108 - val_total_loss: 295.4668 - val_recon_loss: 293.1162 - val_kl_loss: 2.3505 - lr: 0.0010
# Epoch 7/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 265.8082 - recon_loss: 263.2449 - kl_loss: 2.5633 - val_total_loss: 282.6373 - val_recon_loss: 279.7697 - val_kl_loss: 2.8676 - lr: 0.0010
# Epoch 8/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 262.2832 - recon_loss: 259.8264 - kl_loss: 2.4568 - val_total_loss: 284.3871 - val_recon_loss: 282.0945 - val_kl_loss: 2.2926 - lr: 0.0010
# Epoch 9/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 261.2274 - recon_loss: 258.8266 - kl_loss: 2.4008 - val_total_loss: 288.4150 - val_recon_loss: 285.3647 - val_kl_loss: 3.0504 - lr: 0.0010
# Epoch 10/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 261.3500 - recon_loss: 258.2481 - kl_loss: 3.1019 - val_total_loss: 295.3058 - val_recon_loss: 291.9333 - val_kl_loss: 3.3725 - lr: 0.0010
# Epoch 11/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 260.8937 - recon_loss: 257.7531 - kl_loss: 3.1406 - val_total_loss: 282.6386 - val_recon_loss: 279.1129 - val_kl_loss: 3.5257 - lr: 0.0010
# Epoch 12/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 253.3052 - recon_loss: 249.8165 - kl_loss: 3.4886 - val_total_loss: 289.6722 - val_recon_loss: 286.3676 - val_kl_loss: 3.3045 - lr: 0.0010
# Epoch 13/1000
# 28/28 [==============================] - 2s 68ms/step - total_loss: 250.1501 - recon_loss: 246.9033 - kl_loss: 3.2468 - val_total_loss: 295.3127 - val_recon_loss: 291.9147 - val_kl_loss: 3.3980 - lr: 0.0010
# Epoch 14/1000
# 28/28 [==============================] - 2s 68ms/step - total_loss: 250.6447 - recon_loss: 246.8466 - kl_loss: 3.7982 - val_total_loss: 306.8928 - val_recon_loss: 302.6891 - val_kl_loss: 4.2037 - lr: 0.0010
# Epoch 15/1000
# 28/28 [==============================] - 2s 71ms/step - total_loss: 246.2076 - recon_loss: 242.2685 - kl_loss: 3.9392 - val_total_loss: 293.9864 - val_recon_loss: 290.1807 - val_kl_loss: 3.8056 - lr: 0.0010
# Epoch 16/1000
# 28/28 [==============================] - 2s 75ms/step - total_loss: 248.5093 - recon_loss: 244.7851 - kl_loss: 3.7242 - val_total_loss: 273.3588 - val_recon_loss: 269.5037 - val_kl_loss: 3.8551 - lr: 0.0010
# Epoch 17/1000
# 28/28 [==============================] - 2s 76ms/step - total_loss: 251.1425 - recon_loss: 247.1331 - kl_loss: 4.0094 - val_total_loss: 279.5918 - val_recon_loss: 275.6911 - val_kl_loss: 3.9008 - lr: 0.0010
# Epoch 18/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 252.2899 - recon_loss: 248.5454 - kl_loss: 3.7445 - val_total_loss: 301.5005 - val_recon_loss: 297.4204 - val_kl_loss: 4.0801 - lr: 0.0010
# Epoch 19/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 235.7354 - recon_loss: 231.8277 - kl_loss: 3.9078 - val_total_loss: 307.6626 - val_recon_loss: 303.1443 - val_kl_loss: 4.5183 - lr: 0.0010
# Epoch 20/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 221.6430 - recon_loss: 217.2816 - kl_loss: 4.3613 - val_total_loss: 347.8248 - val_recon_loss: 342.9146 - val_kl_loss: 4.9102 - lr: 0.0010
# Epoch 21/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 237.0130 - recon_loss: 232.8309 - kl_loss: 4.1820 - val_total_loss: 313.9257 - val_recon_loss: 309.8237 - val_kl_loss: 4.1020 - lr: 0.0010
# Epoch 22/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 236.2519 - recon_loss: 232.1048 - kl_loss: 4.1472 - val_total_loss: 297.0847 - val_recon_loss: 292.7576 - val_kl_loss: 4.3271 - lr: 0.0010
# Epoch 23/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 241.6574 - recon_loss: 237.7366 - kl_loss: 3.9208 - val_total_loss: 302.8470 - val_recon_loss: 298.4873 - val_kl_loss: 4.3597 - lr: 0.0010
# Epoch 24/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 230.2198 - recon_loss: 226.3523 - kl_loss: 3.8675 - val_total_loss: 294.2700 - val_recon_loss: 289.5579 - val_kl_loss: 4.7120 - lr: 0.0010
# Epoch 25/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 235.1786 - recon_loss: 230.8432 - kl_loss: 4.3354 - val_total_loss: 282.1483 - val_recon_loss: 277.2736 - val_kl_loss: 4.8747 - lr: 0.0010
# Epoch 26/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 240.9590 - recon_loss: 236.7044 - kl_loss: 4.2545 - val_total_loss: 278.9238 - val_recon_loss: 274.5625 - val_kl_loss: 4.3613 - lr: 0.0010
# Epoch 27/1000
# 28/28 [==============================] - 2s 74ms/step - total_loss: 236.2393 - recon_loss: 232.1449 - kl_loss: 4.0944 - val_total_loss: 374.1885 - val_recon_loss: 369.3549 - val_kl_loss: 4.8336 - lr: 0.0010
# Epoch 28/1000
# 28/28 [==============================] - 2s 72ms/step - total_loss: 226.8315 - recon_loss: 222.4503 - kl_loss: 4.3812 - val_total_loss: 375.8656 - val_recon_loss: 370.8966 - val_kl_loss: 4.9690 - lr: 0.0010
# Epoch 29/1000
# 28/28 [==============================] - 2s 69ms/step - total_loss: 212.4461 - recon_loss: 208.2367 - kl_loss: 4.2095 - val_total_loss: 324.6487 - val_recon_loss: 320.0547 - val_kl_loss: 4.5940 - lr: 0.0010
# Epoch 30/1000
# 28/28 [==============================] - 2s 69ms/step - total_loss: 215.1995 - recon_loss: 210.4622 - kl_loss: 4.7372 - val_total_loss: 562.8202 - val_recon_loss: 558.0061 - val_kl_loss: 4.8141 - lr: 0.0010
# Epoch 31/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 244.1714 - recon_loss: 239.9999 - kl_loss: 4.1715 - val_total_loss: 296.3972 - val_recon_loss: 291.7619 - val_kl_loss: 4.6353 - lr: 0.0010
# Epoch 32/1000
# 28/28 [==============================] - 2s 72ms/step - total_loss: 216.2919 - recon_loss: 211.8505 - kl_loss: 4.4414 - val_total_loss: 348.4995 - val_recon_loss: 343.3857 - val_kl_loss: 5.1139 - lr: 0.0010
# Epoch 33/1000
# 28/28 [==============================] - 2s 79ms/step - total_loss: 237.7694 - recon_loss: 232.9095 - kl_loss: 4.8599 - val_total_loss: 280.3020 - val_recon_loss: 275.4639 - val_kl_loss: 4.8381 - lr: 0.0010
# Epoch 34/1000
# 28/28 [==============================] - 2s 72ms/step - total_loss: 248.1832 - recon_loss: 243.6839 - kl_loss: 4.4994 - val_total_loss: 283.8627 - val_recon_loss: 279.3907 - val_kl_loss: 4.4720 - lr: 0.0010
# Epoch 35/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 234.6745 - recon_loss: 230.5393 - kl_loss: 4.1351 - val_total_loss: 317.6944 - val_recon_loss: 312.9966 - val_kl_loss: 4.6978 - lr: 0.0010
# Epoch 36/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 230.1633 - recon_loss: 225.7522 - kl_loss: 4.4111 - val_total_loss: 302.8822 - val_recon_loss: 297.3784 - val_kl_loss: 5.5038 - lr: 0.0010
# Epoch 37/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 228.1347 - recon_loss: 223.4504 - kl_loss: 4.6843 - val_total_loss: 304.0382 - val_recon_loss: 299.3165 - val_kl_loss: 4.7216 - lr: 0.0010
# Epoch 38/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 236.3397 - recon_loss: 232.1295 - kl_loss: 4.2103 - val_total_loss: 328.0867 - val_recon_loss: 323.3466 - val_kl_loss: 4.7401 - lr: 0.0010
# Epoch 39/1000
# 28/28 [==============================] - 2s 70ms/step - total_loss: 226.5889 - recon_loss: 222.3424 - kl_loss: 4.2465 - val_total_loss: 318.2682 - val_recon_loss: 313.6056 - val_kl_loss: 4.6626 - lr: 0.0010
# Epoch 40/1000
# 28/28 [==============================] - 2s 75ms/step - total_loss: 209.8307 - recon_loss: 205.7951 - kl_loss: 4.0356 - val_total_loss: 428.1973 - val_recon_loss: 423.3402 - val_kl_loss: 4.8571 - lr: 0.0010
# Epoch 41/1000
# 28/28 [==============================] - 2s 70ms/step - total_loss: 223.2746 - recon_loss: 219.1987 - kl_loss: 4.0760 - val_total_loss: 349.6476 - val_recon_loss: 345.1842 - val_kl_loss: 4.4634 - lr: 0.0010
# Epoch 42/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 234.6309 - recon_loss: 230.7528 - kl_loss: 3.8780 - val_total_loss: 314.9590 - val_recon_loss: 310.6043 - val_kl_loss: 4.3547 - lr: 0.0010
# Epoch 43/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 231.0259 - recon_loss: 226.8155 - kl_loss: 4.2104 - val_total_loss: 337.2333 - val_recon_loss: 332.6210 - val_kl_loss: 4.6123 - lr: 0.0010
# Epoch 44/1000
# 28/28 [==============================] - 2s 72ms/step - total_loss: 228.9809 - recon_loss: 224.6395 - kl_loss: 4.3414 - val_total_loss: 308.7282 - val_recon_loss: 303.8498 - val_kl_loss: 4.8785 - lr: 0.0010
# Epoch 45/1000
# 28/28 [==============================] - 2s 70ms/step - total_loss: 225.2191 - recon_loss: 220.8783 - kl_loss: 4.3408 - val_total_loss: 368.0446 - val_recon_loss: 363.1723 - val_kl_loss: 4.8723 - lr: 0.0010
# Epoch 46/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 225.4241 - recon_loss: 221.2450 - kl_loss: 4.1791 - val_total_loss: 328.0673 - val_recon_loss: 324.0183 - val_kl_loss: 4.0490 - lr: 0.0010
# Epoch 47/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 210.1075 - recon_loss: 206.2111 - kl_loss: 3.8964 - val_total_loss: 372.4206 - val_recon_loss: 367.8076 - val_kl_loss: 4.6130 - lr: 0.0010
# Epoch 48/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 210.0212 - recon_loss: 205.5499 - kl_loss: 4.4714 - val_total_loss: 270.4978 - val_recon_loss: 265.3290 - val_kl_loss: 5.1688 - lr: 0.0010
# Epoch 49/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 213.6336 - recon_loss: 209.1007 - kl_loss: 4.5329 - val_total_loss: 300.5469 - val_recon_loss: 295.6698 - val_kl_loss: 4.8772 - lr: 0.0010
# Epoch 50/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 221.5879 - recon_loss: 216.6445 - kl_loss: 4.9434 - val_total_loss: 339.1429 - val_recon_loss: 333.3631 - val_kl_loss: 5.7799 - lr: 0.0010
# Epoch 51/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 209.7066 - recon_loss: 204.7189 - kl_loss: 4.9878 - val_total_loss: 269.8039 - val_recon_loss: 264.0696 - val_kl_loss: 5.7343 - lr: 0.0010
# Epoch 52/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 210.6643 - recon_loss: 205.5434 - kl_loss: 5.1209 - val_total_loss: 326.1841 - val_recon_loss: 320.7339 - val_kl_loss: 5.4502 - lr: 0.0010
# Epoch 53/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 190.9370 - recon_loss: 185.9483 - kl_loss: 4.9887 - val_total_loss: 327.3708 - val_recon_loss: 321.9279 - val_kl_loss: 5.4430 - lr: 0.0010
# Epoch 54/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 177.1003 - recon_loss: 172.1581 - kl_loss: 4.9422 - val_total_loss: 298.9334 - val_recon_loss: 293.6893 - val_kl_loss: 5.2442 - lr: 0.0010
# Epoch 55/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 182.6900 - recon_loss: 177.9029 - kl_loss: 4.7871 - val_total_loss: 308.7664 - val_recon_loss: 303.4451 - val_kl_loss: 5.3213 - lr: 0.0010
# Epoch 56/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 197.3095 - recon_loss: 192.4248 - kl_loss: 4.8847 - val_total_loss: 328.5728 - val_recon_loss: 323.5287 - val_kl_loss: 5.0441 - lr: 0.0010
# Epoch 57/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 168.6637 - recon_loss: 163.8008 - kl_loss: 4.8629 - val_total_loss: 381.9226 - val_recon_loss: 376.5047 - val_kl_loss: 5.4178 - lr: 0.0010
# Epoch 58/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 184.1502 - recon_loss: 179.3600 - kl_loss: 4.7902 - val_total_loss: 337.6130 - val_recon_loss: 332.3621 - val_kl_loss: 5.2509 - lr: 0.0010
# Epoch 59/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 173.0803 - recon_loss: 168.2949 - kl_loss: 4.7854 - val_total_loss: 308.7657 - val_recon_loss: 303.5744 - val_kl_loss: 5.1913 - lr: 0.0010
# Epoch 60/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 176.0766 - recon_loss: 171.3248 - kl_loss: 4.7518 - val_total_loss: 332.0569 - val_recon_loss: 326.8207 - val_kl_loss: 5.2361 - lr: 0.0010
# Epoch 61/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 175.9494 - recon_loss: 171.0136 - kl_loss: 4.9358 - val_total_loss: 314.6988 - val_recon_loss: 309.7165 - val_kl_loss: 4.9823 - lr: 0.0010
# Epoch 62/1000
# 28/28 [==============================] - 4s 155ms/step - total_loss: 179.9748 - recon_loss: 175.5146 - kl_loss: 4.4602 - val_total_loss: 346.3351 - val_recon_loss: 341.3627 - val_kl_loss: 4.9724 - lr: 0.0010
# Epoch 63/1000
# 28/28 [==============================] - 2s 84ms/step - total_loss: 170.6112 - recon_loss: 165.8514 - kl_loss: 4.7598 - val_total_loss: 279.0048 - val_recon_loss: 274.2124 - val_kl_loss: 4.7925 - lr: 0.0010
# Epoch 64/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 170.3881 - recon_loss: 165.7703 - kl_loss: 4.6178 - val_total_loss: 420.5158 - val_recon_loss: 415.0357 - val_kl_loss: 5.4801 - lr: 0.0010
# Epoch 65/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 169.5316 - recon_loss: 164.6985 - kl_loss: 4.8331 - val_total_loss: 303.2585 - val_recon_loss: 298.3006 - val_kl_loss: 4.9580 - lr: 0.0010
# Epoch 66/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 165.3416 - recon_loss: 160.5557 - kl_loss: 4.7859 - val_total_loss: 410.1865 - val_recon_loss: 404.9193 - val_kl_loss: 5.2672 - lr: 0.0010
# Epoch 67/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 165.7440 - recon_loss: 161.1056 - kl_loss: 4.6384 - val_total_loss: 344.7036 - val_recon_loss: 339.7883 - val_kl_loss: 4.9153 - lr: 0.0010
# Epoch 68/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 163.8649 - recon_loss: 159.0370 - kl_loss: 4.8279 - val_total_loss: 362.8991 - val_recon_loss: 357.3093 - val_kl_loss: 5.5898 - lr: 0.0010
# Epoch 69/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 156.3336 - recon_loss: 151.6129 - kl_loss: 4.7207 - val_total_loss: 307.6852 - val_recon_loss: 302.8199 - val_kl_loss: 4.8653 - lr: 0.0010
# Epoch 70/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 159.1250 - recon_loss: 154.2313 - kl_loss: 4.8937 - val_total_loss: 384.6455 - val_recon_loss: 379.2229 - val_kl_loss: 5.4226 - lr: 0.0010
# Epoch 71/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 160.3433 - recon_loss: 155.5353 - kl_loss: 4.8080 - val_total_loss: 294.9607 - val_recon_loss: 290.1763 - val_kl_loss: 4.7845 - lr: 0.0010
# Epoch 72/1000
# 28/28 [==============================] - 2s 69ms/step - total_loss: 152.2360 - recon_loss: 147.6568 - kl_loss: 4.5791 - val_total_loss: 400.8036 - val_recon_loss: 395.2346 - val_kl_loss: 5.5690 - lr: 0.0010
# Epoch 73/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 167.6274 - recon_loss: 162.6289 - kl_loss: 4.9985 - val_total_loss: 338.1000 - val_recon_loss: 332.8276 - val_kl_loss: 5.2724 - lr: 0.0010
# Epoch 74/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 164.9936 - recon_loss: 160.1313 - kl_loss: 4.8623 - val_total_loss: 363.8127 - val_recon_loss: 358.9184 - val_kl_loss: 4.8943 - lr: 0.0010
# Epoch 75/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 171.9506 - recon_loss: 167.2662 - kl_loss: 4.6844 - val_total_loss: 355.2450 - val_recon_loss: 350.0374 - val_kl_loss: 5.2077 - lr: 0.0010
# Epoch 76/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 159.0104 - recon_loss: 154.1375 - kl_loss: 4.8729 - val_total_loss: 315.8289 - val_recon_loss: 310.8084 - val_kl_loss: 5.0204 - lr: 0.0010
# Epoch 77/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 186.3171 - recon_loss: 181.4877 - kl_loss: 4.8294 - val_total_loss: 384.5786 - val_recon_loss: 379.2383 - val_kl_loss: 5.3404 - lr: 0.0010
# Epoch 78/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 166.7962 - recon_loss: 161.9420 - kl_loss: 4.8542 - val_total_loss: 345.6561 - val_recon_loss: 340.4966 - val_kl_loss: 5.1594 - lr: 0.0010
# Epoch 79/1000
# 28/28 [==============================] - 2s 62ms/step - total_loss: 161.0555 - recon_loss: 156.1752 - kl_loss: 4.8804 - val_total_loss: 382.5614 - val_recon_loss: 377.2815 - val_kl_loss: 5.2800 - lr: 0.0010
# Epoch 80/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 158.3783 - recon_loss: 153.5518 - kl_loss: 4.8265 - val_total_loss: 336.0032 - val_recon_loss: 330.8402 - val_kl_loss: 5.1630 - lr: 0.0010
# Epoch 81/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 156.6050 - recon_loss: 151.7706 - kl_loss: 4.8344 - val_total_loss: 389.7451 - val_recon_loss: 384.6662 - val_kl_loss: 5.0789 - lr: 0.0010
# Epoch 82/1000
# 28/28 [==============================] - 2s 65ms/step - total_loss: 157.7223 - recon_loss: 152.7380 - kl_loss: 4.9843 - val_total_loss: 318.1239 - val_recon_loss: 312.7207 - val_kl_loss: 5.4032 - lr: 0.0010
# Epoch 83/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 161.1036 - recon_loss: 156.1730 - kl_loss: 4.9306 - val_total_loss: 369.3005 - val_recon_loss: 364.0936 - val_kl_loss: 5.2070 - lr: 0.0010
# Epoch 84/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 151.8781 - recon_loss: 147.0828 - kl_loss: 4.7953 - val_total_loss: 367.4313 - val_recon_loss: 362.4159 - val_kl_loss: 5.0155 - lr: 0.0010
# Epoch 85/1000
# 28/28 [==============================] - 2s 63ms/step - total_loss: 146.4890 - recon_loss: 141.5785 - kl_loss: 4.9105 - val_total_loss: 357.7452 - val_recon_loss: 352.2164 - val_kl_loss: 5.5288 - lr: 0.0010
# Epoch 86/1000
# 28/28 [==============================] - 2s 64ms/step - total_loss: 145.3666 - recon_loss: 140.4019 - kl_loss: 4.9647 - val_total_loss: 359.2047 - val_recon_loss: 354.2044 - val_kl_loss: 5.0003 - lr: 0.0010
# Epoch 87/1000
# 28/28 [==============================] - 2s 77ms/step - total_loss: 145.3439 - recon_loss: 140.1974 - kl_loss: 5.1465 - val_total_loss: 364.8446 - val_recon_loss: 359.0957 - val_kl_loss: 5.7488 - lr: 0.0010
# Epoch 88/1000
# 28/28 [==============================] - 2s 71ms/step - total_loss: 147.6481 - recon_loss: 142.3891 - kl_loss: 5.2590 - val_total_loss: 381.6583 - val_recon_loss: 375.9887 - val_kl_loss: 5.6695 - lr: 0.0010
# Epoch 89/1000
# 28/28 [==============================] - 2s 70ms/step - total_loss: 149.0138 - recon_loss: 143.7991 - kl_loss: 5.2147 - val_total_loss: 360.7509 - val_recon_loss: 355.1815 - val_kl_loss: 5.5694 - lr: 0.0010
# Epoch 90/1000
# 28/28 [==============================] - 2s 71ms/step - total_loss: 144.3797 - recon_loss: 138.8746 - kl_loss: 5.5051 - val_total_loss: 405.9304 - val_recon_loss: 400.2687 - val_kl_loss: 5.6617 - lr: 0.0010
# Epoch 91/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 146.0824 - recon_loss: 140.8781 - kl_loss: 5.2043 - val_total_loss: 323.8565 - val_recon_loss: 318.2845 - val_kl_loss: 5.5720 - lr: 0.0010
# Epoch 92/1000
# 28/28 [==============================] - 2s 70ms/step - total_loss: 145.0082 - recon_loss: 139.7551 - kl_loss: 5.2531 - val_total_loss: 369.3938 - val_recon_loss: 363.7691 - val_kl_loss: 5.6247 - lr: 0.0010
# Epoch 93/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 168.1244 - recon_loss: 162.6065 - kl_loss: 5.5179 - val_total_loss: 309.5986 - val_recon_loss: 304.3024 - val_kl_loss: 5.2962 - lr: 0.0010
# Epoch 94/1000
# 28/28 [==============================] - 2s 70ms/step - total_loss: 235.7303 - recon_loss: 230.1032 - kl_loss: 5.6271 - val_total_loss: 287.3333 - val_recon_loss: 281.5720 - val_kl_loss: 5.7613 - lr: 0.0010
# Epoch 95/1000
# 28/28 [==============================] - 3s 97ms/step - total_loss: 196.4398 - recon_loss: 190.8651 - kl_loss: 5.5747 - val_total_loss: 425.1594 - val_recon_loss: 419.0459 - val_kl_loss: 6.1135 - lr: 0.0010
# Epoch 96/1000
# 28/28 [==============================] - 3s 91ms/step - total_loss: 168.5305 - recon_loss: 163.0071 - kl_loss: 5.5233 - val_total_loss: 347.7520 - val_recon_loss: 341.7772 - val_kl_loss: 5.9748 - lr: 0.0010
# Epoch 97/1000
# 28/28 [==============================] - 2s 69ms/step - total_loss: 154.4313 - recon_loss: 148.7883 - kl_loss: 5.6430 - val_total_loss: 298.9460 - val_recon_loss: 293.0452 - val_kl_loss: 5.9008 - lr: 0.0010
# Epoch 98/1000
# 28/28 [==============================] - 2s 66ms/step - total_loss: 149.7266 - recon_loss: 144.1758 - kl_loss: 5.5508 - val_total_loss: 323.8792 - val_recon_loss: 317.9720 - val_kl_loss: 5.9071 - lr: 0.0010
# Epoch 99/1000
# 28/28 [==============================] - 2s 67ms/step - total_loss: 136.1567 - recon_loss: 130.5067 - kl_loss: 5.6500 - val_total_loss: 369.5325 - val_recon_loss: 363.5905 - val_kl_loss: 5.9420 - lr: 0.0010
# Epoch 100/1000
# 28/28 [==============================] - 2s 71ms/step - total_loss: 145.9283 - recon_loss: 140.3215 - kl_loss: 5.6067 - val_total_loss: 396.2708 - val_recon_loss: 390.7736 - val_kl_loss: 5.4972 - lr: 0.0010
# Epoch 101/1000
# 28/28 [==============================] - ETA: 0s - total_loss: 256.7216 - recon_loss: 251.2663 - kl_loss: 5.4553
# Epoch 101: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
# 28/28 [==============================] - 2s 64ms/step - total_loss: 256.7216 - recon_loss: 251.2663 - kl_loss: 5.4553 - val_total_loss: 312.3956 - val_recon_loss: 306.7223 - val_kl_loss: 5.6733 - lr: 0.0010
# Epoch 101: early stopping

# %%
training_history = fitting_output.history

# %%
# plotting the decrease in loss as the network learns
fig_loss = plt.figure()
ax = fig_loss.add_subplot(111)
ax.plot(fitting_output.history['total_loss'], label='Training')
ax.plot(fitting_output.history['val_total_loss'], label='Validation')
ax.set_title('Decrease in Loss')
ax.set_ylabel('Loss', fontsize=20)
ax.set_xlabel('Epoch', fontsize=20)
ax.legend(loc='upper right', fontsize=14)
ax.tick_params(axis='both', which='both', labelsize=12)
# ax.set_xticks(np.arange(0, epochs, 1))
# ax.set_ylim(0, 25)
plt.show()

# %% [markdown]
# ## testing the model

# %%
# compare autoencoder model to encoder and decoder models

# f1 = autoencoder.predict([x_test, rtimes_te])
f2 = decoder(np.concatenate((encoder(x_test)[2].numpy(), rtimes_te), axis=1))

# %%
# plt.plot(answers_te, f1, 'o')
plt.plot(answers_te, f2, 'o')

# %%
encoded_data = encoder(x_test)[2]

# %%
fig = plt.figure(figsize=(20, 20))

fontsize = 20

# Kappa plots
ax1 = fig.add_subplot(551)
ax1.plot(kappas_te, encoded_data[:, 0], 'o', alpha=0.2)
ax1.set_xlabel('kappa', fontsize=fontsize)
ax1.set_ylabel('neuron 0', fontsize=fontsize)

ax2 = fig.add_subplot(552)
ax2.plot(kappas_te, encoded_data[:, 1], 'o', alpha=0.2)
ax2.set_xlabel('kappa', fontsize=fontsize)
ax2.set_ylabel('neuron 1', fontsize=fontsize)

ax3 = fig.add_subplot(553)
ax3.plot(kappas_te, encoded_data[:, 2], 'o', alpha=0.2)
ax3.set_xlabel('kappa', fontsize=fontsize)
ax3.set_ylabel('neuron 2', fontsize=fontsize)

ax4 = fig.add_subplot(554)
ax4.plot(kappas_te, encoded_data[:, 3], 'o', alpha=0.2)
ax4.set_xlabel('kappa', fontsize=fontsize)
ax4.set_ylabel('neuron 3', fontsize=fontsize)

ax5 = fig.add_subplot(555)
ax5.plot(kappas_te, encoded_data[:, 4], 'o', alpha=0.2)
ax5.set_xlabel('kappa', fontsize=fontsize)
ax5.set_ylabel('neuron 4', fontsize=fontsize)

# Beta plots
ax6 = fig.add_subplot(556)
ax6.plot(betas_te, encoded_data[:, 0], 'o', alpha=0.2)
ax6.set_xlabel('beta', fontsize=fontsize)
ax6.set_ylabel('neuron 0', fontsize=fontsize)

ax7 = fig.add_subplot(557)
ax7.plot(betas_te, encoded_data[:, 1], 'o', alpha=0.2)
ax7.set_xlabel('beta', fontsize=fontsize)
ax7.set_ylabel('neuron 1', fontsize=fontsize)

ax8 = fig.add_subplot(558)
ax8.plot(betas_te, encoded_data[:, 2], 'o', alpha=0.2)
ax8.set_xlabel('beta', fontsize=fontsize)
ax8.set_ylabel('neuron 2', fontsize=fontsize)

ax9 = fig.add_subplot(559)
ax9.plot(betas_te, encoded_data[:, 3], 'o', alpha=0.2)
ax9.set_xlabel('beta', fontsize=fontsize)
ax9.set_ylabel('neuron 3', fontsize=fontsize)

ax10 = fig.add_subplot(5, 5, 10)
ax10.plot(betas_te, encoded_data[:, 4], 'o', alpha=0.2)
ax10.set_xlabel('beta', fontsize=fontsize)
ax10.set_ylabel('neuron 4', fontsize=fontsize)

# A plots
ax11 = fig.add_subplot(5, 5, 11)
ax11.plot(As_te, encoded_data[:, 0], 'o', alpha=0.2)
ax11.set_xlabel('A', fontsize=fontsize)
ax11.set_ylabel('neuron 0', fontsize=fontsize)

ax12 = fig.add_subplot(5, 5, 12)
ax12.plot(As_te, encoded_data[:, 1], 'o', alpha=0.2)
ax12.set_xlabel('A', fontsize=fontsize)
ax12.set_ylabel('neuron 1', fontsize=fontsize)

ax13 = fig.add_subplot(5, 5, 13)
ax13.plot(As_te, encoded_data[:, 2], 'o', alpha=0.2)
ax13.set_xlabel('A', fontsize=fontsize)
ax13.set_ylabel('neuron 2', fontsize=fontsize)

ax14 = fig.add_subplot(5, 5, 14)
ax14.plot(As_te, encoded_data[:, 3], 'o', alpha=0.2)
ax14.set_xlabel('A', fontsize=fontsize)
ax14.set_ylabel('neuron 3', fontsize=fontsize)

ax15 = fig.add_subplot(5, 5, 15)
ax15.plot(As_te, encoded_data[:, 4], 'o', alpha=0.2)
ax15.set_xlabel('A', fontsize=fontsize)
ax15.set_ylabel('neuron 4', fontsize=fontsize)

# Omega plots
ax16 = fig.add_subplot(5, 5, 16)
ax16.plot(omegas_te, encoded_data[:, 0], 'o', alpha=0.2)
ax16.set_xlabel('omega', fontsize=fontsize)
ax16.set_ylabel('neuron 0', fontsize=fontsize)

ax17 = fig.add_subplot(5, 5, 17)
ax17.plot(omegas_te, encoded_data[:, 1], 'o', alpha=0.2)
ax17.set_xlabel('omega', fontsize=fontsize)
ax17.set_ylabel('neuron 1', fontsize=fontsize)

ax18 = fig.add_subplot(5, 5, 18)
ax18.plot(omegas_te, encoded_data[:, 2], 'o', alpha=0.2)
ax18.set_xlabel('omega', fontsize=fontsize)
ax18.set_ylabel('neuron 2', fontsize=fontsize)

ax19 = fig.add_subplot(5, 5, 19)
ax19.plot(omegas_te, encoded_data[:, 3], 'o', alpha=0.2)
ax19.set_xlabel('omega', fontsize=fontsize)
ax19.set_ylabel('neuron 3', fontsize=fontsize)

ax20 = fig.add_subplot(5, 5, 20)
ax20.plot(omegas_te, encoded_data[:, 4], 'o', alpha=0.2)
ax20.set_xlabel('omega', fontsize=fontsize)
ax20.set_ylabel('neuron 4', fontsize=fontsize)

plt.tight_layout()

graphs_file_path = f"klq_b:{batch_size}_lr:{learning_rate}_r:{regul}_r2:{regul2}"
plt.savefig(f"{graphs_file_path}.png")
plt.show()
plt.close(fig)

# %%
plt.hist(encoded_data[:,3])
# Out:
# (array([1.000e+00, 2.000e+00, 4.000e+00, 6.000e+00, 1.260e+02, 1.291e+03,
#         5.230e+02, 3.100e+01, 1.000e+01, 6.000e+00]),
#  array([-8.192661 , -6.721885 , -5.251109 , -3.780333 , -2.309557 ,
#         -0.8387809,  0.6319952,  2.1027713,  3.5735474,  5.0443234,
#          6.5150995], dtype=float32),
#  <BarContainer object of 10 artists>)

# %%
sample = 96

plt.plot(x_test[sample], color='g', marker='o', alpha=0.2)
# plt.plot(f1[sample], color='b', marker='*', alpha=0.2)
plt.plot(f2[sample], color='r', marker='s', alpha=0.2)
